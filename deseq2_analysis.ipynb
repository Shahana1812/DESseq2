# %%
# **DESeq2 Analysis **

# %%
# Load necessary
library(DESeq2)
library(tidyverse)

# %%
counts_data <- read.csv ('/home/icb/shahana.dilruba/transposed_count_table.csv')

# %%
head(counts_data)
# Out:
#   X          X0                        X1
# 1 Unnamed: 0 muc21058_AAACCCAAGTTTGAGA muc21058_AAACCCACACGCGCAT
# 2 SAMD11     0.0                       0.0
# 3 NOC2L      0.0                       0.0
# 4 KLHL17     0.0                       0.0
# 5 PLEKHN1    0.0                       0.4794558882713318
# 6 PERM1      0.0                       0.0
#   X2                        X3                        X4
# 1 muc21058_AAACCCACAGACACAG muc21058_AAACCCAGTATTGCCA muc21058_AAACCCAGTCGTATTG
# 2 0.0                       0.0                       0.0
# 3 0.0                       0.0                       0.5631203055381775
# 4 0.0                       0.0                       0.0
# 5 0.2667522430419922        0.0                       0.0
# 6 0.0                       0.0                       0.0
#   X5                        X6                        X7
# 1 muc21058_AAACCCAGTGCGAACA muc21058_AAACCCATCCAACTGA muc21058_AAACCCATCCGCCTAT
# ...

# %%
colData <- read.csv ('/home/icb/shahana.dilruba/sample_names.csv')

# %%
colData
# Out:
#        SampleName
# 1      muc21058
# 2      muc21058
# 3      muc21058
# 4      muc21058
# 5      muc21058
# 6      muc21058
# 7      muc21058
# 8      muc21058
# 9      muc21058
# 10     muc21058
# 11     muc21058
# 12     muc21058
# 13     muc21058
# 14     muc21058
# 15     muc21058
# 16     muc21058
# 17     muc21058
# 18     muc21058
# 19     muc21058
# 20     muc21058
# 21     muc21058
# 22     muc21058
# 23     muc21058
# 24     muc21058
# 25     muc21058
# 26     muc21058
# 27     muc21058
# 28     muc21058
# 29     muc21058
# 30     muc21058
# ⋮      ⋮
# 254601 muc22968
# 254602 muc22968
# 254603 muc22968
# 254604 muc22968
# 254605 muc22968
# 254606 muc22968
# 254607 muc22968
# 254608 muc22968
# 254609 muc22968
# 254610 muc22968
# 254611 muc22968
# 254612 muc22968
# 254613 muc22968
# 254614 muc22968
# 254615 muc22968
# 254616 muc22968
# 254617 muc22968
# 254618 muc22968
# 254619 muc22968
# 254620 muc22968
# 254621 muc22968
# 254622 muc22968
# 254623 muc22968
# ...

# %%
all(rownames(counts_data)%in% colnames(colData))
# Out:
# [1] FALSE

# %%
 #Step 2: construct a DESeqDataSet object ----------

dds <- DESeqDataSetFromMatrix(countData = counts_data,
                       colData = colData,
                       design = ~ treatment)
# Out:
# Error in DESeqDataSetFromMatrix(countData = counts_data, colData = colData, : ncol(countData) == nrow(colData) is not TRUE
# Traceback:
#
# 1. DESeqDataSetFromMatrix(countData = counts_data, colData = colData,
#  .     design = ~treatment)
# 2. stopifnot(ncol(countData) == nrow(colData))
